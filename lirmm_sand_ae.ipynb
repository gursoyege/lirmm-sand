# %% [markdown]
# <a href="https://colab.research.google.com/github/gursoyege/lirmm-sand/blob/master/lirmm_sand_ae.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Verify the GPU, if not Tesla P100, maybe reset runtime and reconnect.

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Thu Jul  2 15:45:34 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.36.06    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# Connect to google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# Imports

# %%
import glob
import imageio
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import keras
from keras.models import model_from_yaml

from numpy.random import default_rng, randint
from keras.models import Model
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, Flatten, Conv2DTranspose, Reshape, LeakyReLU
from keras.optimizers import Adam
from keras import backend as K

# %% [markdown]
# Define image dataset and R values

# %%
def get_data(folder_path , act_num):
    beginning = 1
    trainFolder = sorted(glob.glob(folder_path))
    act = trainFolder[0]
    actionFolder = sorted(glob.glob(act + "*/"))
    for ins_e, ins in enumerate(actionFolder):
        instanceFolder = sorted(glob.glob(ins + "*/"))
        for cla_e, cla in enumerate(instanceFolder):
            classFolder = sorted(glob.glob(cla + "/*.png"))
            for img_e, img in enumerate(classFolder):
                tensor = tf.io.read_file(img)
                print(img)
                tensor = tf.io.decode_image(tensor, dtype=tf.dtypes.uint8)
                tensor = tf.image.convert_image_dtype(tensor, tf.float32)
                if beginning == 1:
                    img_w,img_h,img_d = tensor.shape
                    cla_n = len(instanceFolder)
                    img_n = len(classFolder)
                    set_complete = np.zeros((len(actionFolder) ,len(instanceFolder) ,len(classFolder), img_w, img_h, 1), dtype = 'float32')
                   
                    beginning = 0
                set_complete[ins_e,cla_e,img_e,:,:,:] = tensor
    return img_w, img_h, cla_n, img_n, set_complete


def get_r_val(folder_path , act_num):
    r_all = np.array([])
    beginning = 1
    rFolder = sorted(glob.glob(folder_path))
    
    act = rFolder[0]
    
    actionFolder = sorted(glob.glob(act + "*/"))
    
    for ins_e, ins in enumerate(actionFolder):
        instanceFolder = sorted(glob.glob(ins + "*.npy"))
        for r_e, r in enumerate(instanceFolder):
            print(r)
            r_act = np.load(r)
            if beginning == 1:
                r_shape = r_act.shape
                r_all = np.zeros((cla_n, r_shape[0], r_shape[1], 1))
                r_all[r_e,:,:,:] = r_act
                beginning = 0
            else :
                r_all[r_e,:,:,:] = r_act
    return r_all

# %% [markdown]
# Get the image dataset and R values

# %%
img_w, img_h, cla_n, img_n, set_complete = get_data("/content/drive/My Drive/lirmm-sand/train_lite/*/", 0)
r_all = get_r_val("/content/drive/My Drive/lirmm-sand/r_value/*/", 0)

U0 = 424
V0 = 240
FX = 417
FY = 377
r_max = np.sqrt(1 + (U0/FX)**2 + (V0/FY)**2)
# Out:
# /content/drive/My Drive/lirmm-sand/train_lite/poke/beg/1beg/1beg_0.png
# /content/drive/My Drive/lirmm-sand/train_lite/poke/beg/2beg/2beg_0.png
# /content/drive/My Drive/lirmm-sand/train_lite/poke/beg/3beg/3beg_0.png
# /content/drive/My Drive/lirmm-sand/train_lite/poke/beg/4beg/4beg_0.png
# /content/drive/My Drive/lirmm-sand/train_lite/poke/beg/5beg/5beg_0.png
# /content/drive/My Drive/lirmm-sand/train_lite/poke/beg/6beg/6beg_0.png
# /content/drive/My Drive/lirmm-sand/train_lite/poke/beg/7beg/7beg_0.png
# /content/drive/My Drive/lirmm-sand/train_lite/poke/beg/8beg/8beg_0.png
# /content/drive/My Drive/lirmm-sand/train_lite/poke/beg/9beg/9beg_0.png
# /content/drive/My Drive/lirmm-sand/train_lite/poke/end/1end/1end_0.png
# /content/drive/My Drive/lirmm-sand/train_lite/poke/end/2end/2end_0.png
# /content/drive/My Drive/lirmm-sand/train_lite/poke/end/3end/3end_0.png
# /content/drive/My Drive/lirmm-sand/train_lite/poke/end/4end/4end_0.png
# /content/drive/My Drive/lirmm-sand/train_lite/poke/end/5end/5end_0.png
# /content/drive/My Drive/lirmm-sand/train_lite/poke/end/6end/6end_0.png
# /content/drive/My Drive/lirmm-sand/train_lite/poke/end/7end/7end_0.png
# /content/drive/My Drive/lirmm-sand/train_lite/poke/end/8end/8end_0.png
# /content/drive/My Drive/lirmm-sand/train_lite/poke/end/9end/9end_0.png
# /content/drive/My Drive/lirmm-sand/r_value/poke/beg/1.npy
# /content/drive/My Drive/lirmm-sand/r_value/poke/beg/2.npy
# /content/drive/My Drive/lirmm-sand/r_value/poke/beg/3.npy
# /content/drive/My Drive/lirmm-sand/r_value/poke/beg/4.npy
# /content/drive/My Drive/lirmm-sand/r_value/poke/beg/5.npy
# /content/drive/My Drive/lirmm-sand/r_value/poke/beg/6.npy
# /content/drive/My Drive/lirmm-sand/r_value/poke/beg/7.npy
# /content/drive/My Drive/lirmm-sand/r_value/poke/beg/8.npy
# /content/drive/My Drive/lirmm-sand/r_value/poke/beg/9.npy
# /content/drive/My Drive/lirmm-sand/r_value/poke/end/1.npy
# /content/drive/My Drive/lirmm-sand/r_value/poke/end/2.npy
# /content/drive/My Drive/lirmm-sand/r_value/poke/end/3.npy
# /content/drive/My Drive/lirmm-sand/r_value/poke/end/4.npy
# /content/drive/My Drive/lirmm-sand/r_value/poke/end/5.npy
# /content/drive/My Drive/lirmm-sand/r_value/poke/end/6.npy
# /content/drive/My Drive/lirmm-sand/r_value/poke/end/7.npy
# /content/drive/My Drive/lirmm-sand/r_value/poke/end/8.npy
# /content/drive/My Drive/lirmm-sand/r_value/poke/end/9.npy

# %% [markdown]
# Create train and test sets

# %%
cla_n = 7
train_set = set_complete[:,0:cla_n,:,:,:,:]

_t, _t, _t, _t, set_complete2 = get_data("/content/drive/My Drive/lirmm-sand/test_lite/*/", 0)

test_set = set_complete2[:,:,:,:,:,:]
test_pick = np.zeros((9,1,img_w,img_h,1))
test_ground = np.zeros((9,1,img_w,img_h,1))
for i in range(9):
    rand_img = randint(img_n)
    test_pick[i,0,:,:,:] = test_set[0,i,rand_img,:,:,:]
    test_ground[i,0,:,:,:] = test_set[1,i,rand_img,:,:,:]
# Out:
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/1beg/1beg_0.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/1beg/1beg_1.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/1beg/1beg_2.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/1beg/1beg_3.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/1beg/1beg_4.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/1beg/1beg_5.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/1beg/1beg_6.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/1beg/1beg_7.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/1beg/1beg_8.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/1beg/1beg_9.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/2beg/2beg_0.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/2beg/2beg_1.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/2beg/2beg_2.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/2beg/2beg_3.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/2beg/2beg_4.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/2beg/2beg_5.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/2beg/2beg_6.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/2beg/2beg_7.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/2beg/2beg_8.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/2beg/2beg_9.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/3beg/3beg_0.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/3beg/3beg_1.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/3beg/3beg_2.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/3beg/3beg_3.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/3beg/3beg_4.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/3beg/3beg_5.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/3beg/3beg_6.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/3beg/3beg_7.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/3beg/3beg_8.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/3beg/3beg_9.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/4beg/4beg_0.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/4beg/4beg_1.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/4beg/4beg_2.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/4beg/4beg_3.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/4beg/4beg_4.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/4beg/4beg_5.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/4beg/4beg_6.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/4beg/4beg_7.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/4beg/4beg_8.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/4beg/4beg_9.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/5beg/5beg_0.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/5beg/5beg_1.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/5beg/5beg_2.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/5beg/5beg_3.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/5beg/5beg_4.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/5beg/5beg_5.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/5beg/5beg_6.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/5beg/5beg_7.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/5beg/5beg_8.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/5beg/5beg_9.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/6beg/6beg_0.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/6beg/6beg_1.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/6beg/6beg_2.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/6beg/6beg_3.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/6beg/6beg_4.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/6beg/6beg_5.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/6beg/6beg_6.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/6beg/6beg_7.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/6beg/6beg_8.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/6beg/6beg_9.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/7beg/7beg_0.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/7beg/7beg_1.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/7beg/7beg_2.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/7beg/7beg_3.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/7beg/7beg_4.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/7beg/7beg_5.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/7beg/7beg_6.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/7beg/7beg_7.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/7beg/7beg_8.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/7beg/7beg_9.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/8beg/8beg_0.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/8beg/8beg_1.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/8beg/8beg_2.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/8beg/8beg_3.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/8beg/8beg_4.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/8beg/8beg_5.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/8beg/8beg_6.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/8beg/8beg_7.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/8beg/8beg_8.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/8beg/8beg_9.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/9beg/9beg_0.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/9beg/9beg_1.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/9beg/9beg_2.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/9beg/9beg_3.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/9beg/9beg_4.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/9beg/9beg_5.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/9beg/9beg_6.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/9beg/9beg_7.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/9beg/9beg_8.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/beg/9beg/9beg_9.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/1end/1end_0.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/1end/1end_1.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/1end/1end_2.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/1end/1end_3.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/1end/1end_4.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/1end/1end_5.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/1end/1end_6.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/1end/1end_7.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/1end/1end_8.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/1end/1end_9.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/2end/2end_0.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/2end/2end_1.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/2end/2end_2.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/2end/2end_3.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/2end/2end_4.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/2end/2end_5.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/2end/2end_6.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/2end/2end_7.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/2end/2end_8.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/2end/2end_9.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/3end/3end_0.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/3end/3end_1.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/3end/3end_2.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/3end/3end_3.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/3end/3end_4.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/3end/3end_5.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/3end/3end_6.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/3end/3end_7.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/3end/3end_8.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/3end/3end_9.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/4end/4end_0.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/4end/4end_1.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/4end/4end_2.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/4end/4end_3.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/4end/4end_4.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/4end/4end_5.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/4end/4end_6.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/4end/4end_7.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/4end/4end_8.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/4end/4end_9.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/5end/5end_0.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/5end/5end_1.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/5end/5end_2.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/5end/5end_3.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/5end/5end_4.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/5end/5end_5.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/5end/5end_6.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/5end/5end_7.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/5end/5end_8.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/5end/5end_9.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/6end/6end_0.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/6end/6end_1.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/6end/6end_2.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/6end/6end_3.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/6end/6end_4.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/6end/6end_5.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/6end/6end_6.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/6end/6end_7.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/6end/6end_8.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/6end/6end_9.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/7end/7end_0.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/7end/7end_1.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/7end/7end_2.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/7end/7end_3.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/7end/7end_4.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/7end/7end_5.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/7end/7end_6.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/7end/7end_7.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/7end/7end_8.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/7end/7end_9.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/8end/8end_0.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/8end/8end_1.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/8end/8end_2.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/8end/8end_3.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/8end/8end_4.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/8end/8end_5.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/8end/8end_6.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/8end/8end_7.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/8end/8end_8.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/8end/8end_9.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/9end/9end_0.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/9end/9end_1.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/9end/9end_2.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/9end/9end_3.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/9end/9end_4.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/9end/9end_5.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/9end/9end_6.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/9end/9end_7.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/9end/9end_8.png
# /content/drive/My Drive/lirmm-sand/test_lite/poke/end/9end/9end_9.png

# %% [markdown]
# Define epoch, batch, and loss

# %%
def make_epoch(set_complete):
    ins_e,cla_e,img_e,img_h,img_w,img_d=set_complete.shape
    cla_rand = np.zeros(cla_e)
    img_rand = np.zeros(img_e)
    rng = default_rng()
    
    cla_rand[:] = rng.choice(cla_e, size=cla_e, replace=False)
    img_rand[:] = rng.choice(img_e, size=img_e, replace=False)


    cla_rang = np.tile(cla_rand,img_e)
    img_rang = np.repeat(img_rand, cla_e)

    cla_iter = iter(cla_rang)
    img_iter = iter(img_rang)
    return cla_iter, img_iter , cla_rang, img_rang


def make_batch(set_complete, cla_iter, img_iter, batch_size):
    ins_e,cla_e,img_e,img_h,img_w,img_d=set_complete.shape
    r_batch = np.zeros((batch_size,img_h,img_w,img_d),dtype='float32')
    input_batch = np.zeros((batch_size,img_h,img_w,img_d),dtype='float32')
    ground_batch = np.zeros((batch_size,img_h,img_w,img_d),dtype='float32')
    for i in range(batch_size):
        cla_pick = next(cla_iter, None)
        img_pick = next(img_iter, None)
        if cla_pick == None or img_pick == None:
            break
        r_batch[i,:,:,:] = r_all[int(cla_pick), :,:,:]
        input_batch[i,:,:,:] = set_complete[0,int(cla_pick),int(img_pick),:,:,:]        
        ground_batch[i,:,:,:] = set_complete[1,int(cla_pick),int(img_pick),:,:,:]
    return input_batch, ground_batch, r_batch


def custom_loss(r, img_w, img_h, r_max):
    img_w = K.constant(img_w)
    img_h = K.constant(img_h)
    r_max = K.constant(r_max)
    def loss(y_true, y_pred):
        loss_value = K.sum((r * K.abs(y_pred - y_true)))/(img_w * img_h * r_max)
        return loss_value
    return loss

# %% [markdown]
# Create model

# %%
input_img = Input(shape=(img_w, img_h, 1),name='input')

x = Conv2D(32, (5, 5), padding='same', name='conv1')(input_img)
x = LeakyReLU(alpha=0.2, name='leaky1')(x)
x = MaxPooling2D((2, 2), padding='same', name='pool1')(x)
x = Conv2D(64, (5, 5), padding='same', name='conv2')(x)
x = LeakyReLU(alpha=0.2, name='leaky2')(x)
x = MaxPooling2D((2, 2), padding='same', name='pool2')(x)
x = Conv2D(128, (1, 1), padding='same', name='conv3')(x)
x = LeakyReLU(alpha=0.2, name='leaky3')(x)
x = MaxPooling2D((2, 2), padding='same', name='pool3')(x)

shape = x.shape
x = Flatten(name='flatten_conv2fc')(x)

x = Dense(7200, activation='relu', name='fc_encoder')(x)
x = Dense(4096, activation='relu', name='fc_latent')(x)
x = Dense(7200, activation='relu', name='fc_decoder')(x)

x = Dense(shape[1]*shape[2]*shape[3], activation='linear', name='map_fc2deconv')(x)
x = Reshape((shape[1],shape[2],shape[3]), name='reshape_fc2deconv')(x)

x = UpSampling2D((2, 2), name='unpool1')(x)
x = Conv2DTranspose(64, (1, 1), activation='relu', padding='same', name='deconv1')(x)
x = UpSampling2D((2, 2), name='unpool2')(x)
x = Conv2DTranspose(32, (5, 5), activation='relu', padding='same', name='deconv2')(x)
x = UpSampling2D((2, 2), name='unpool3')(x)
x = Conv2DTranspose(1, (5, 5), activation='relu', padding='same', name='deconv3')(x)

decoded = keras.layers.Lambda(lambda x: x[:,0:img_w,0:img_h,:], name='reshape_out')(x)

r = K.variable(np.zeros([1,img_w,img_h,1]))
autoencoder = Model(input_img, decoded, name='autoencoder')
autoencoder.summary()
autoencoder.compile(optimizer=Adam(lr=0.0002, beta_1=0.5), loss=custom_loss(r,img_w,img_h,r_max))
# Out:
# Model: "autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           (None, 52, 55, 1)         0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 52, 55, 32)        832
# _________________________________________________________________
# leaky1 (LeakyReLU)           (None, 52, 55, 32)        0
# _________________________________________________________________
# pool1 (MaxPooling2D)         (None, 26, 28, 32)        0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 26, 28, 64)        51264
# _________________________________________________________________
# leaky2 (LeakyReLU)           (None, 26, 28, 64)        0
# _________________________________________________________________
# pool2 (MaxPooling2D)         (None, 13, 14, 64)        0
# _________________________________________________________________
# conv3 (Conv2D)               (None, 13, 14, 128)       8320
# _________________________________________________________________
# leaky3 (LeakyReLU)           (None, 13, 14, 128)       0
# _________________________________________________________________
# pool3 (MaxPooling2D)         (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten_conv2fc (Flatten)    (None, 6272)              0
# _________________________________________________________________
# fc_encoder (Dense)           (None, 7200)              45165600
# _________________________________________________________________
# fc_latent (Dense)            (None, 4096)              29495296
# _________________________________________________________________
# fc_decoder (Dense)           (None, 7200)              29498400
# _________________________________________________________________
# map_fc2deconv (Dense)        (None, 6272)              45164672
# _________________________________________________________________
# reshape_fc2deconv (Reshape)  (None, 7, 7, 128)         0
# _________________________________________________________________
# unpool1 (UpSampling2D)       (None, 14, 14, 128)       0
# _________________________________________________________________
# deconv1 (Conv2DTranspose)    (None, 14, 14, 64)        8256
# _________________________________________________________________
# unpool2 (UpSampling2D)       (None, 28, 28, 64)        0
# _________________________________________________________________
# deconv2 (Conv2DTranspose)    (None, 28, 28, 32)        51232
# _________________________________________________________________
# unpool3 (UpSampling2D)       (None, 56, 56, 32)        0
# _________________________________________________________________
# deconv3 (Conv2DTranspose)    (None, 56, 56, 1)         801
# _________________________________________________________________
# reshape_out (Lambda)         (None, 52, 55, 1)         0
# =================================================================
# Total params: 149,444,673
# Trainable params: 149,444,673
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Training parameters

# %%
EPOCHS = 5000
CLA_PASS = 1 #CLA_PASS sample from each class
batch_size = CLA_PASS * cla_n
step_per_epoch = int(np.ceil(img_n*cla_n/batch_size))

# %% [markdown]
# Train loop

# %%
for epoch in range(EPOCHS):
    cla_iter, img_iter , cla_rang, img_rang = make_epoch(train_set)

    for step in range(step_per_epoch):
        input_batch, ground_batch, r_batch = make_batch(train_set, cla_iter, img_iter, batch_size)
        input_iter = iter(input_batch)
        ground_iter = iter(ground_batch)
        r_iter = iter(r_batch)

        for i in range(batch_size):
            inputs = next(input_iter)
            grounds = next(ground_iter)
            r_values = next(r_iter)

            if not np.any(inputs): # if input = all zeros
                break
            
            inputs = np.expand_dims(inputs, axis=0)
            grounds = np.expand_dims(grounds, axis=0)
            r_values = np.expand_dims(r_values, axis=0)

            r.assign(r_values)

            loss_out = autoencoder.train_on_batch(inputs, grounds)
    if epoch%100 == 0:
        print('Epoch: ', epoch, ' loss: ', loss_out)
    if epoch%1000 == 0:
        autoencoder.save_weights("/content/drive/My Drive/lirmm-sand/saved_model/model" + str(epoch) + ".h5")
# Out:
# Epoch:  0  loss:  0.015249954
# Epoch:  100  loss:  0.034214754
# Epoch:  200  loss:  0.06975994
# Epoch:  300  loss:  0.030080616
# Epoch:  400  loss:  0.008548995
# Epoch:  500  loss:  0.025781201
# Epoch:  600  loss:  0.023443589
# Epoch:  700  loss:  0.012501027
# Epoch:  800  loss:  0.044528995
# Epoch:  900  loss:  0.0068578473
# Epoch:  1000  loss:  0.012471557
# Epoch:  1100  loss:  0.03209533
# Epoch:  1200  loss:  0.028294144
# Epoch:  1300  loss:  0.010360568
# Epoch:  1400  loss:  0.03545878
# Epoch:  1500  loss:  0.03765747
# Epoch:  1600  loss:  0.008611736
# Epoch:  1700  loss:  0.029690303
# Epoch:  1800  loss:  0.014949155
# Epoch:  1900  loss:  0.0064490517
# Epoch:  2000  loss:  0.0064332867
# Epoch:  2100  loss:  0.02023519
# Epoch:  2200  loss:  0.009375012
# Epoch:  2300  loss:  0.01034515
# Epoch:  2400  loss:  0.033137385
# Epoch:  2500  loss:  0.016511478
# Epoch:  2600  loss:  0.01294754
# Epoch:  2700  loss:  0.0081930505
# Epoch:  2800  loss:  0.011343294
# Epoch:  2900  loss:  0.013202349
# Epoch:  3000  loss:  0.01364052
# Epoch:  3100  loss:  0.022763226
# Epoch:  3200  loss:  0.00823377
# Epoch:  3300  loss:  0.005647175
# Epoch:  3400  loss:  0.0060394024
# Epoch:  3500  loss:  0.01985767
# Epoch:  3600  loss:  0.010299092
# Epoch:  3700  loss:  0.019543419
# Epoch:  3800  loss:  0.009086917
# Epoch:  3900  loss:  0.01878967
# Epoch:  4000  loss:  0.011567946
# Epoch:  4100  loss:  0.010782271
# Epoch:  4200  loss:  0.0112708835
# Epoch:  4300  loss:  0.016497167
# Epoch:  4400  loss:  0.014997466
# Epoch:  4500  loss:  0.0121395085
# Epoch:  4600  loss:  0.0062403814
# Epoch:  4700  loss:  0.014880014
# Epoch:  4800  loss:  0.010836165
# Epoch:  4900  loss:  0.0121631995

# %% [markdown]
# Test loop

# %%
model_weights= sorted(glob.glob("/content/drive/My Drive/lirmm-sand/saved_model/*.h5"))
autoencoder.load_weights(model_weights[-1])

for i in range(9):
    j=0
    j += 1
    plt.subplot(1,3,j)
    imgs = test_pick[i,:,:,:,:] 
    plt.imshow(imgs[0,:,:,0], cmap="gray")
    
    j += 1
    plt.subplot(1,3,j)
    gnds = test_ground[i,:,:,:,:] 
    plt.imshow(gnds[0,:,:,0], cmap="gray")
    
    j += 1
    plt.subplot(1,3,j)
    decoded_imgs = autoencoder.predict(imgs)
    plt.imshow(decoded_imgs[0,:,:,0], cmap="gray")

    plt.show()
